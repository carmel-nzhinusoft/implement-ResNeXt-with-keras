# %% [markdown]
# # Implement ResNeXt with Keras
#
# *By **Carmel WENGA** Deep Learning Ingineer, Nzhinusoft*
#
#
# **ResNeXt** : an image classification model proposed by *Xie et al. (2017)* in <a href="https://arxiv.org/pdf/1611.05431.pdf">Aggregated Residual Transformations for Deep Neural Networks</a>
#
# ## Import Requirements

# %%
from keras.layers import Activation
from keras.layers import Add
from keras.layers import AveragePooling2D
from keras.layers import BatchNormalization
from keras.layers import Concatenate
from keras.layers import Conv2D
from keras.layers import Dense
from keras.layers import Flatten
from keras.layers import GlobalMaxPooling2D
from keras.layers import Input
from keras.layers import Lambda
from keras.layers import MaxPooling2D
from keras.layers import ZeroPadding2D
from keras.models import Model
from keras.optimizers import Adam
from keras.initializers import glorot_uniform
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # 1. Implement Split-Transform-Merge functions

# %% [markdown]
# ## a. The Split function
#
# The original implementation of **ResNeXt** uses grouped convolution to implement the split operation. This function divides its input channels into groups. The total number of group is define by the cardinality which is equals to 4 in our case. The building block implement here is shown in the following image. It's the first reformulation of the original building block of the **ResNeXt** model.
#
# <img src="images/building-block.png" width="300"/>
#
# Inputs are represented as 4-dimensional tensor where the last dimension represent the number of channels. If the input's shape is $(x,y,z,c)$, the `split()` function returns a list (`groups`) of 4 tensors with following shapes: $(x,y,z,c_1)$, $(x,y,z,c_2)$, $(x,y,z,c_3)$ and $(x,y,z,c_4)$. The number of channel per group (`group_size`) equals to input channels (`inputs_channels`) divides by the cardinality.

# %%
def split(inputs, cardinality):
    inputs_channels = inputs.shape[3]
    group_size = inputs_channels // cardinality    
    groups = list()
    for number in range(1, cardinality+1):
        begin = int((number-1)*group_size)
        end = int(number*group_size)
        block = Lambda(lambda x:x[:,:,:,begin:end])(inputs)
        groups.append(block)
    return groups

# %% [markdown]
# ## b. Transform and Merge operations
#
# After the splitting operation, tensors corresponding to each group are transformed through a set of convolutional operations in the `transform()` function. As shown in the above figure, these operations are $1\times1$ and $3\times3$ convolutional layers (`Conv2D`) respectively. Each convolutional layer is followed by `BatchNormalization` and `ReLU` layers. Once the transformation operation as been applied to all groups, the returned tensors are concatenated through the `Concatenate` layer. This is the **Merge** operation.

# %%
def transform(groups, filters, strides, stage, block):
    f1, f2 = filters    
    conv_name = "conv2d-{stage}{block}-branch".format(stage=str(stage), block=str(block))
    bn_name = "batchnorm-{stage}{block}-branch".format(stage=str(stage), block=str(block))
    
    transformed_tensor = list()
    i = 1
    
    for inputs in groups:
        # first conv of the transformation phase
        x = Conv2D(filters=f1, kernel_size=(1,1), strides=strides, padding="valid", 
                   name=conv_name+'1a_split'+str(i), kernel_initializer=glorot_uniform(seed=0))(inputs)
        x = BatchNormalization(axis=3, name=bn_name+'1a_split'+str(i))(x)
        x = Activation('relu')(x)

        # second conv of the transformation phase
        x = Conv2D(filters=f2, kernel_size=(3,3), strides=(1,1), padding="same", 
                   name=conv_name+'1b_split'+str(i), kernel_initializer=glorot_uniform(seed=0))(x)
        x = BatchNormalization(axis=3, name=bn_name+'1b_split'+str(i))(x)
        x = Activation('relu')(x)
        
        # Add x to transformed tensor list
        transformed_tensor.append(x)
        i+=1
        
    # Concatenate all tensor from each group
    x = Concatenate(name='concat'+str(stage)+''+block)(transformed_tensor)
    
    return x

# %% [markdown]
# ## c. The Transition phase
#
# The last layer of the above building block realizes $1\times1$ convolutions on the return tensor of `transform()` function. This is what does the `transition()` function.

# %%
def transition(inputs, filters, stage, block):
    x = Conv2D(filters=filters, kernel_size=(1,1), strides=(1,1), padding="valid", 
                   name='conv2d-trans'+str(stage)+''+block, kernel_initializer=glorot_uniform(seed=0))(inputs)
    x = BatchNormalization(axis=3, name='batchnorm-trans'+str(stage)+''+block)(x)
    x = Activation('relu')(x)
    
    return x

# %% [markdown]
# # 2. Implement Residual Blocks
#
# To implement the **ResNeXt** architecture, we consider two types of Residual or Building block. We consider `identity_block` and `downsampling`. As describe in the figure below, **ResNeXt-50** is composed of four stages that contain 3, 4, 6 and 3 building blocks respectively.
#
# <img src="images/resnext-archi.png" width="350"/>
#
# As described by **He *et al.***(2016) in their paper <a href="https://www.cv-foundation.org/openaccess/content_cvpr_2016/papers/He_Deep_Residual_Learning_CVPR_2016_paper.pdf">Deep Residual Learning for Image Recognition</a>, ***Identity Shortcut*** are used when the input and the output are of the same dimensions. Building blocks contained is the same stage are have the same input and output. They are `identity_block` and the ***Identity Shorcut*** defined by the function `identity_block()` can be use. Important parameters of this latter are :
#
# <ul>
#     <li> <b>inputs</b> : the input tensor of the building block</li>
#     <li> <b>filters</b> : it is a set of three filters corresponding to the output channels of the first, second and third convolutional operation of the building block
#     <li> <b>strides</b> : equals to (1,1) for identity blocks
# </ul>

# %%
def identity_block(inputs, filters, cardinality, stage, block, strides=(1,1)):
    
    conv_name = "conv2d-{stage}{block}-branch".format(stage=str(stage),block=str(block))
    bn_name = "batchnorm-{stage}{block}-branch".format(stage=str(stage),block=str(block))
    
    #save the input tensor value
    x_shortcut = inputs
    x = inputs
    
    f1, f2, f3 = filters
    
    # divide input channels into groups. The number of groups is define by cardinality param
    groups = split(inputs=x, cardinality=cardinality)
    
    # transform each group by doing a set of convolutions and concat the results
    f1 = int(f1 / cardinality)
    f2 = int(f2 / cardinality)
    x = transform(groups=groups, filters=(f1, f2), strides=strides, stage=stage, block=block)
    
    # make a transition by doing 1x1 conv
    x = transition(inputs=x, filters=f3, stage=stage, block=block)
    
    # Last step of the identity block, shortcut concatenation
    x = Add()([x,x_shortcut])
    x = Activation('relu')(x)
    
    return x

# %% [markdown]
# When transit from a stage to another stage, input's heigth and width are divided by 2 using strides of 2. The input and output are then of different dimensions. In this case, we use the `downsampling()` function in which we use the **Projection Shortcut** to match dimensions before doing the `Add()` operation.

# %%
def downsampling(inputs, filters, cardinality, strides, stage, block):
    
    # useful variables
    conv_name = "conv2d-{stage}{block}-branch".format(stage=str(stage), block=str(block))
    bn_name = "batchnorm-{stage}{block}-branch".format(stage=str(stage), block=str(block))
    
    # Retrieve filters for each layer
    f1, f2, f3 = filters
    
    # save the input tensor value
    x_shortcut = inputs
    x = inputs
    
    # divide input channels into groups. The number of groups is define by cardinality param
    groups = split(inputs=x, cardinality=cardinality)
    
    # transform each group by doing a set of convolutions and concat the results
    f1 = int(f1 / cardinality)
    f2 = int(f2 / cardinality)
    x = transform(groups=groups, filters=(f1, f2), strides=strides, stage=stage, block=block)
    
    # make a transition by doing 1x1 conv
    x = transition(inputs=x, filters=f3, stage=stage, block=block)
    
    # Projection Shortcut to match dimensions 
    x_shortcut = Conv2D(filters=f3, kernel_size=(1,1), strides=strides, padding="valid", 
               name='{base}2'.format(base=conv_name), kernel_initializer=glorot_uniform(seed=0))(x_shortcut)
    x_shortcut = BatchNormalization(axis=3, name='{base}2'.format(base=bn_name))(x_shortcut)
    
    # Add x and x_shortcut
    x = Add()([x,x_shortcut])
    x = Activation('relu')(x)
    
    return x

# %% [markdown]
# # ResNeXt-50
#
# The following `ResNeXt50()` function uses previews defined functions to build the **ResNeXt-50** architecture. We considered the first stage of the architecture as the first convolutional layer (`conv2D`) with the three operations that follows it. The other stages of the architecture all start with the `downsampling` building block and the rest of its blocks are `identity_block`. After all building block stages, follows and average pooling (`AveragePooling2D`). The network ends with fully connected layer identify with the `Dense` layer.

# %%
def ResNeXt50(input_shape, classes):
    
    # Transform input to a tensor of shape input_shape 
    x_input = Input(input_shape)
    
    # Add zero padding
    x = ZeroPadding2D((3,3))(x_input)
    
    # Initial Stage. Let's say stage 1
    x = Conv2D(filters=64, kernel_size=(7,7), strides=(2,2), 
               name='conv2d_1', kernel_initializer=glorot_uniform(seed=0))(x)
    x = BatchNormalization(axis=3, name='batchnorm_1')(x)
    x = Activation('relu')(x)
    x = MaxPooling2D((3,3), strides=(2,2))(x)
    
    # Stage 2
    x = downsampling(inputs=x, filters=(128,128,256), cardinality=4, strides=(2,2), stage=2, block="a")
    x = identity_block(inputs=x, filters=(128,128,256), cardinality=4, stage=2, block="b")
    x = identity_block(inputs=x, filters=(128,128,256), cardinality=4, stage=2, block="c")
    
    
    # Stage 3
    x = downsampling(inputs=x, filters=(256,256,512), cardinality=4, strides=(2,2), stage=3, block="a")
    x = identity_block(inputs=x, filters=(256,256,512), cardinality=4, stage=3, block="b")
    x = identity_block(inputs=x, filters=(256,256,512), cardinality=4, stage=3, block="c")
    x = identity_block(inputs=x, filters=(256,256,512), cardinality=4, stage=3, block="d")
    
    
    # Stage 4
    x = downsampling(inputs=x, filters=(512,512,1024), cardinality=4, strides=(2,2), stage=4, block="a")
    x = identity_block(inputs=x, filters=(512,512,1024), cardinality=4, stage=4, block="b")
    x = identity_block(inputs=x, filters=(512,512,1024), cardinality=4, stage=4, block="c")
    x = identity_block(inputs=x, filters=(512,512,1024), cardinality=4, stage=4, block="d")
    x = identity_block(inputs=x, filters=(512,512,1024), cardinality=4, stage=4, block="e")
    x = identity_block(inputs=x, filters=(512,512,1024), cardinality=4, stage=4, block="f")
    
    
    # Stage 5
    x = downsampling(inputs=x, filters=(1024,1024,2048), cardinality=4, strides=(2,2), stage=5, block="a")
    x = identity_block(inputs=x, filters=(1024,1024,2048), cardinality=4, stage=5, block="b")
    x = identity_block(inputs=x, filters=(1024,1024,2048), cardinality=4, stage=5, block="c")
    
    
    # Average pooling
    x = AveragePooling2D(pool_size=(2,2), padding="same")(x)
    
    # Output layer
    x = Flatten()(x)
    x = Dense(classes, activation="softmax", kernel_initializer=glorot_uniform(seed=0), 
              name="fc{cls}".format(cls=str(classes)))(x)
    
    # Create the model
    model = Model(inputs=x_input, outputs=x, name="resnet50")
    
    return model

# %% [markdown]
# Build the **ResNeXt50** model with input shape of $(224,224,3)$ for 2 classes.

# %%
model = ResNeXt50(input_shape=(224,224,3), classes=2)
# Out:
# WARNING:tensorflow:From /home/nzhinusoft/python/machine-learning/ml-venv/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %%
optimizer = Adam(lr=0.0001)
model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])

# %%
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 224, 224, 3)  0
# __________________________________________________________________________________________________
# zero_padding2d_1 (ZeroPadding2D (None, 230, 230, 3)  0           input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 112, 112, 64) 9472        zero_padding2d_1[0][0]
# __________________________________________________________________________________________________
# batchnorm_1 (BatchNormalization (None, 112, 112, 64) 256         conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 112, 112, 64) 0           batchnorm_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 55, 55, 64)   0           activation_1[0][0]
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 55, 55, 16)   0           max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# lambda_2 (Lambda)               (None, 55, 55, 16)   0           max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# lambda_3 (Lambda)               (None, 55, 55, 16)   0           max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# lambda_4 (Lambda)               (None, 55, 55, 16)   0           max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d-2a-branch1a_split1 (Conv (None, 28, 28, 32)   544         lambda_1[0][0]
# __________________________________________________________________________________________________
# conv2d-2a-branch1a_split2 (Conv (None, 28, 28, 32)   544         lambda_2[0][0]
# __________________________________________________________________________________________________
# conv2d-2a-branch1a_split3 (Conv (None, 28, 28, 32)   544         lambda_3[0][0]
# __________________________________________________________________________________________________
# conv2d-2a-branch1a_split4 (Conv (None, 28, 28, 32)   544         lambda_4[0][0]
# __________________________________________________________________________________________________
# batchnorm-2a-branch1a_split1 (B (None, 28, 28, 32)   128         conv2d-2a-branch1a_split1[0][0]
# __________________________________________________________________________________________________
# batchnorm-2a-branch1a_split2 (B (None, 28, 28, 32)   128         conv2d-2a-branch1a_split2[0][0]
# __________________________________________________________________________________________________
# batchnorm-2a-branch1a_split3 (B (None, 28, 28, 32)   128         conv2d-2a-branch1a_split3[0][0]
# __________________________________________________________________________________________________
# batchnorm-2a-branch1a_split4 (B (None, 28, 28, 32)   128         conv2d-2a-branch1a_split4[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 28, 28, 32)   0           batchnorm-2a-branch1a_split1[0][0
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 28, 28, 32)   0           batchnorm-2a-branch1a_split2[0][0
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 28, 28, 32)   0           batchnorm-2a-branch1a_split3[0][0
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 28, 28, 32)   0           batchnorm-2a-branch1a_split4[0][0
# __________________________________________________________________________________________________
# conv2d-2a-branch1b_split1 (Conv (None, 28, 28, 32)   9248        activation_2[0][0]
# __________________________________________________________________________________________________
# conv2d-2a-branch1b_split2 (Conv (None, 28, 28, 32)   9248        activation_4[0][0]
# __________________________________________________________________________________________________
# conv2d-2a-branch1b_split3 (Conv (None, 28, 28, 32)   9248        activation_6[0][0]
# __________________________________________________________________________________________________
# conv2d-2a-branch1b_split4 (Conv (None, 28, 28, 32)   9248        activation_8[0][0]
# __________________________________________________________________________________________________
# batchnorm-2a-branch1b_split1 (B (None, 28, 28, 32)   128         conv2d-2a-branch1b_split1[0][0]
# __________________________________________________________________________________________________
# batchnorm-2a-branch1b_split2 (B (None, 28, 28, 32)   128         conv2d-2a-branch1b_split2[0][0]
# __________________________________________________________________________________________________
# batchnorm-2a-branch1b_split3 (B (None, 28, 28, 32)   128         conv2d-2a-branch1b_split3[0][0]
# __________________________________________________________________________________________________
# batchnorm-2a-branch1b_split4 (B (None, 28, 28, 32)   128         conv2d-2a-branch1b_split4[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 28, 28, 32)   0           batchnorm-2a-branch1b_split1[0][0
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 28, 28, 32)   0           batchnorm-2a-branch1b_split2[0][0
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 28, 28, 32)   0           batchnorm-2a-branch1b_split3[0][0
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 28, 28, 32)   0           batchnorm-2a-branch1b_split4[0][0
# __________________________________________________________________________________________________
# concat2a (Concatenate)          (None, 28, 28, 128)  0           activation_3[0][0]
#                                                                  activation_5[0][0]
#                                                                  activation_7[0][0]
#                                                                  activation_9[0][0]
# __________________________________________________________________________________________________
# conv2d-trans2a (Conv2D)         (None, 28, 28, 256)  33024       concat2a[0][0]
# __________________________________________________________________________________________________
# batchnorm-trans2a (BatchNormali (None, 28, 28, 256)  1024        conv2d-trans2a[0][0]
# __________________________________________________________________________________________________
# conv2d-2a-branch2 (Conv2D)      (None, 28, 28, 256)  16640       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 28, 28, 256)  0           batchnorm-trans2a[0][0]
# __________________________________________________________________________________________________
# batchnorm-2a-branch2 (BatchNorm (None, 28, 28, 256)  1024        conv2d-2a-branch2[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 28, 28, 256)  0           activation_10[0][0]
#                                                                  batchnorm-2a-branch2[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 28, 28, 256)  0           add_1[0][0]
# __________________________________________________________________________________________________
# lambda_5 (Lambda)               (None, 28, 28, 32)   0           activation_11[0][0]
# __________________________________________________________________________________________________
# lambda_6 (Lambda)               (None, 28, 28, 32)   0           activation_11[0][0]
# __________________________________________________________________________________________________
# lambda_7 (Lambda)               (None, 28, 28, 32)   0           activation_11[0][0]
# __________________________________________________________________________________________________
# lambda_8 (Lambda)               (None, 28, 28, 32)   0           activation_11[0][0]
# __________________________________________________________________________________________________
# conv2d-2b-branch1a_split1 (Conv (None, 28, 28, 32)   1056        lambda_5[0][0]
# __________________________________________________________________________________________________
# conv2d-2b-branch1a_split2 (Conv (None, 28, 28, 32)   1056        lambda_6[0][0]
# __________________________________________________________________________________________________
# conv2d-2b-branch1a_split3 (Conv (None, 28, 28, 32)   1056        lambda_7[0][0]
# __________________________________________________________________________________________________
# conv2d-2b-branch1a_split4 (Conv (None, 28, 28, 32)   1056        lambda_8[0][0]
# __________________________________________________________________________________________________
# batchnorm-2b-branch1a_split1 (B (None, 28, 28, 32)   128         conv2d-2b-branch1a_split1[0][0]
# __________________________________________________________________________________________________
# batchnorm-2b-branch1a_split2 (B (None, 28, 28, 32)   128         conv2d-2b-branch1a_split2[0][0]
# __________________________________________________________________________________________________
# batchnorm-2b-branch1a_split3 (B (None, 28, 28, 32)   128         conv2d-2b-branch1a_split3[0][0]
# __________________________________________________________________________________________________
# batchnorm-2b-branch1a_split4 (B (None, 28, 28, 32)   128         conv2d-2b-branch1a_split4[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 28, 28, 32)   0           batchnorm-2b-branch1a_split1[0][0
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 28, 28, 32)   0           batchnorm-2b-branch1a_split2[0][0
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 28, 28, 32)   0           batchnorm-2b-branch1a_split3[0][0
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 28, 28, 32)   0           batchnorm-2b-branch1a_split4[0][0
# __________________________________________________________________________________________________
# conv2d-2b-branch1b_split1 (Conv (None, 28, 28, 32)   9248        activation_12[0][0]
# __________________________________________________________________________________________________
# conv2d-2b-branch1b_split2 (Conv (None, 28, 28, 32)   9248        activation_14[0][0]
# __________________________________________________________________________________________________
# conv2d-2b-branch1b_split3 (Conv (None, 28, 28, 32)   9248        activation_16[0][0]
# __________________________________________________________________________________________________
# conv2d-2b-branch1b_split4 (Conv (None, 28, 28, 32)   9248        activation_18[0][0]
# __________________________________________________________________________________________________
# batchnorm-2b-branch1b_split1 (B (None, 28, 28, 32)   128         conv2d-2b-branch1b_split1[0][0]
# __________________________________________________________________________________________________
# batchnorm-2b-branch1b_split2 (B (None, 28, 28, 32)   128         conv2d-2b-branch1b_split2[0][0]
# __________________________________________________________________________________________________
# batchnorm-2b-branch1b_split3 (B (None, 28, 28, 32)   128         conv2d-2b-branch1b_split3[0][0]
# __________________________________________________________________________________________________
# batchnorm-2b-branch1b_split4 (B (None, 28, 28, 32)   128         conv2d-2b-branch1b_split4[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 28, 28, 32)   0           batchnorm-2b-branch1b_split1[0][0
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 28, 28, 32)   0           batchnorm-2b-branch1b_split2[0][0
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 28, 28, 32)   0           batchnorm-2b-branch1b_split3[0][0
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 28, 28, 32)   0           batchnorm-2b-branch1b_split4[0][0
# __________________________________________________________________________________________________
# concat2b (Concatenate)          (None, 28, 28, 128)  0           activation_13[0][0]
#                                                                  activation_15[0][0]
#                                                                  activation_17[0][0]
#                                                                  activation_19[0][0]
# __________________________________________________________________________________________________
# conv2d-trans2b (Conv2D)         (None, 28, 28, 256)  33024       concat2b[0][0]
# __________________________________________________________________________________________________
# batchnorm-trans2b (BatchNormali (None, 28, 28, 256)  1024        conv2d-trans2b[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 28, 28, 256)  0           batchnorm-trans2b[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 28, 28, 256)  0           activation_20[0][0]
#                                                                  activation_11[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 28, 28, 256)  0           add_2[0][0]
# __________________________________________________________________________________________________
# lambda_9 (Lambda)               (None, 28, 28, 32)   0           activation_21[0][0]
# __________________________________________________________________________________________________
# lambda_10 (Lambda)              (None, 28, 28, 32)   0           activation_21[0][0]
# __________________________________________________________________________________________________
# lambda_11 (Lambda)              (None, 28, 28, 32)   0           activation_21[0][0]
# __________________________________________________________________________________________________
# lambda_12 (Lambda)              (None, 28, 28, 32)   0           activation_21[0][0]
# __________________________________________________________________________________________________
# conv2d-2c-branch1a_split1 (Conv (None, 28, 28, 32)   1056        lambda_9[0][0]
# __________________________________________________________________________________________________
# conv2d-2c-branch1a_split2 (Conv (None, 28, 28, 32)   1056        lambda_10[0][0]
# __________________________________________________________________________________________________
# conv2d-2c-branch1a_split3 (Conv (None, 28, 28, 32)   1056        lambda_11[0][0]
# __________________________________________________________________________________________________
# conv2d-2c-branch1a_split4 (Conv (None, 28, 28, 32)   1056        lambda_12[0][0]
# __________________________________________________________________________________________________
# batchnorm-2c-branch1a_split1 (B (None, 28, 28, 32)   128         conv2d-2c-branch1a_split1[0][0]
# __________________________________________________________________________________________________
# batchnorm-2c-branch1a_split2 (B (None, 28, 28, 32)   128         conv2d-2c-branch1a_split2[0][0]
# __________________________________________________________________________________________________
# batchnorm-2c-branch1a_split3 (B (None, 28, 28, 32)   128         conv2d-2c-branch1a_split3[0][0]
# __________________________________________________________________________________________________
# batchnorm-2c-branch1a_split4 (B (None, 28, 28, 32)   128         conv2d-2c-branch1a_split4[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 28, 28, 32)   0           batchnorm-2c-branch1a_split1[0][0
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 28, 28, 32)   0           batchnorm-2c-branch1a_split2[0][0
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 28, 28, 32)   0           batchnorm-2c-branch1a_split3[0][0
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 28, 28, 32)   0           batchnorm-2c-branch1a_split4[0][0
# __________________________________________________________________________________________________
# conv2d-2c-branch1b_split1 (Conv (None, 28, 28, 32)   9248        activation_22[0][0]
# __________________________________________________________________________________________________
# conv2d-2c-branch1b_split2 (Conv (None, 28, 28, 32)   9248        activation_24[0][0]
# __________________________________________________________________________________________________
# conv2d-2c-branch1b_split3 (Conv (None, 28, 28, 32)   9248        activation_26[0][0]
# __________________________________________________________________________________________________
# conv2d-2c-branch1b_split4 (Conv (None, 28, 28, 32)   9248        activation_28[0][0]
# __________________________________________________________________________________________________
# batchnorm-2c-branch1b_split1 (B (None, 28, 28, 32)   128         conv2d-2c-branch1b_split1[0][0]
# __________________________________________________________________________________________________
# batchnorm-2c-branch1b_split2 (B (None, 28, 28, 32)   128         conv2d-2c-branch1b_split2[0][0]
# __________________________________________________________________________________________________
# batchnorm-2c-branch1b_split3 (B (None, 28, 28, 32)   128         conv2d-2c-branch1b_split3[0][0]
# __________________________________________________________________________________________________
# batchnorm-2c-branch1b_split4 (B (None, 28, 28, 32)   128         conv2d-2c-branch1b_split4[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 28, 28, 32)   0           batchnorm-2c-branch1b_split1[0][0
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 28, 28, 32)   0           batchnorm-2c-branch1b_split2[0][0
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 28, 28, 32)   0           batchnorm-2c-branch1b_split3[0][0
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 28, 28, 32)   0           batchnorm-2c-branch1b_split4[0][0
# __________________________________________________________________________________________________
# concat2c (Concatenate)          (None, 28, 28, 128)  0           activation_23[0][0]
#                                                                  activation_25[0][0]
#                                                                  activation_27[0][0]
#                                                                  activation_29[0][0]
# __________________________________________________________________________________________________
# conv2d-trans2c (Conv2D)         (None, 28, 28, 256)  33024       concat2c[0][0]
# __________________________________________________________________________________________________
# batchnorm-trans2c (BatchNormali (None, 28, 28, 256)  1024        conv2d-trans2c[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 28, 28, 256)  0           batchnorm-trans2c[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 28, 28, 256)  0           activation_30[0][0]
#                                                                  activation_21[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 28, 28, 256)  0           add_3[0][0]
# __________________________________________________________________________________________________
# lambda_13 (Lambda)              (None, 28, 28, 64)   0           activation_31[0][0]
# __________________________________________________________________________________________________
# lambda_14 (Lambda)              (None, 28, 28, 64)   0           activation_31[0][0]
# __________________________________________________________________________________________________
# lambda_15 (Lambda)              (None, 28, 28, 64)   0           activation_31[0][0]
# __________________________________________________________________________________________________
# lambda_16 (Lambda)              (None, 28, 28, 64)   0           activation_31[0][0]
# __________________________________________________________________________________________________
# conv2d-3a-branch1a_split1 (Conv (None, 14, 14, 64)   4160        lambda_13[0][0]
# __________________________________________________________________________________________________
# conv2d-3a-branch1a_split2 (Conv (None, 14, 14, 64)   4160        lambda_14[0][0]
# __________________________________________________________________________________________________
# conv2d-3a-branch1a_split3 (Conv (None, 14, 14, 64)   4160        lambda_15[0][0]
# __________________________________________________________________________________________________
# conv2d-3a-branch1a_split4 (Conv (None, 14, 14, 64)   4160        lambda_16[0][0]
# __________________________________________________________________________________________________
# batchnorm-3a-branch1a_split1 (B (None, 14, 14, 64)   256         conv2d-3a-branch1a_split1[0][0]
# __________________________________________________________________________________________________
# batchnorm-3a-branch1a_split2 (B (None, 14, 14, 64)   256         conv2d-3a-branch1a_split2[0][0]
# __________________________________________________________________________________________________
# batchnorm-3a-branch1a_split3 (B (None, 14, 14, 64)   256         conv2d-3a-branch1a_split3[0][0]
# __________________________________________________________________________________________________
# batchnorm-3a-branch1a_split4 (B (None, 14, 14, 64)   256         conv2d-3a-branch1a_split4[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 14, 14, 64)   0           batchnorm-3a-branch1a_split1[0][0
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, 14, 14, 64)   0           batchnorm-3a-branch1a_split2[0][0
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, 14, 14, 64)   0           batchnorm-3a-branch1a_split3[0][0
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, 14, 14, 64)   0           batchnorm-3a-branch1a_split4[0][0
# __________________________________________________________________________________________________
# conv2d-3a-branch1b_split1 (Conv (None, 14, 14, 64)   36928       activation_32[0][0]
# __________________________________________________________________________________________________
# conv2d-3a-branch1b_split2 (Conv (None, 14, 14, 64)   36928       activation_34[0][0]
# __________________________________________________________________________________________________
# conv2d-3a-branch1b_split3 (Conv (None, 14, 14, 64)   36928       activation_36[0][0]
# __________________________________________________________________________________________________
# conv2d-3a-branch1b_split4 (Conv (None, 14, 14, 64)   36928       activation_38[0][0]
# __________________________________________________________________________________________________
# batchnorm-3a-branch1b_split1 (B (None, 14, 14, 64)   256         conv2d-3a-branch1b_split1[0][0]
# __________________________________________________________________________________________________
# batchnorm-3a-branch1b_split2 (B (None, 14, 14, 64)   256         conv2d-3a-branch1b_split2[0][0]
# __________________________________________________________________________________________________
# batchnorm-3a-branch1b_split3 (B (None, 14, 14, 64)   256         conv2d-3a-branch1b_split3[0][0]
# __________________________________________________________________________________________________
# batchnorm-3a-branch1b_split4 (B (None, 14, 14, 64)   256         conv2d-3a-branch1b_split4[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, 14, 14, 64)   0           batchnorm-3a-branch1b_split1[0][0
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, 14, 14, 64)   0           batchnorm-3a-branch1b_split2[0][0
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, 14, 14, 64)   0           batchnorm-3a-branch1b_split3[0][0
# __________________________________________________________________________________________________
# activation_39 (Activation)      (None, 14, 14, 64)   0           batchnorm-3a-branch1b_split4[0][0
# __________________________________________________________________________________________________
# concat3a (Concatenate)          (None, 14, 14, 256)  0           activation_33[0][0]
#                                                                  activation_35[0][0]
#                                                                  activation_37[0][0]
#                                                                  activation_39[0][0]
# __________________________________________________________________________________________________
# conv2d-trans3a (Conv2D)         (None, 14, 14, 512)  131584      concat3a[0][0]
# __________________________________________________________________________________________________
# batchnorm-trans3a (BatchNormali (None, 14, 14, 512)  2048        conv2d-trans3a[0][0]
# __________________________________________________________________________________________________
# conv2d-3a-branch2 (Conv2D)      (None, 14, 14, 512)  131584      activation_31[0][0]
# __________________________________________________________________________________________________
# activation_40 (Activation)      (None, 14, 14, 512)  0           batchnorm-trans3a[0][0]
# __________________________________________________________________________________________________
# batchnorm-3a-branch2 (BatchNorm (None, 14, 14, 512)  2048        conv2d-3a-branch2[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 14, 14, 512)  0           activation_40[0][0]
#                                                                  batchnorm-3a-branch2[0][0]
# __________________________________________________________________________________________________
# activation_41 (Activation)      (None, 14, 14, 512)  0           add_4[0][0]
# __________________________________________________________________________________________________
# lambda_17 (Lambda)              (None, 14, 14, 64)   0           activation_41[0][0]
# __________________________________________________________________________________________________
# lambda_18 (Lambda)              (None, 14, 14, 64)   0           activation_41[0][0]
# __________________________________________________________________________________________________
# lambda_19 (Lambda)              (None, 14, 14, 64)   0           activation_41[0][0]
# __________________________________________________________________________________________________
# lambda_20 (Lambda)              (None, 14, 14, 64)   0           activation_41[0][0]
# __________________________________________________________________________________________________
# conv2d-3b-branch1a_split1 (Conv (None, 14, 14, 64)   4160        lambda_17[0][0]
# __________________________________________________________________________________________________
# conv2d-3b-branch1a_split2 (Conv (None, 14, 14, 64)   4160        lambda_18[0][0]
# __________________________________________________________________________________________________
# conv2d-3b-branch1a_split3 (Conv (None, 14, 14, 64)   4160        lambda_19[0][0]
# __________________________________________________________________________________________________
# conv2d-3b-branch1a_split4 (Conv (None, 14, 14, 64)   4160        lambda_20[0][0]
# __________________________________________________________________________________________________
# batchnorm-3b-branch1a_split1 (B (None, 14, 14, 64)   256         conv2d-3b-branch1a_split1[0][0]
# __________________________________________________________________________________________________
# batchnorm-3b-branch1a_split2 (B (None, 14, 14, 64)   256         conv2d-3b-branch1a_split2[0][0]
# __________________________________________________________________________________________________
# batchnorm-3b-branch1a_split3 (B (None, 14, 14, 64)   256         conv2d-3b-branch1a_split3[0][0]
# __________________________________________________________________________________________________
# batchnorm-3b-branch1a_split4 (B (None, 14, 14, 64)   256         conv2d-3b-branch1a_split4[0][0]
# __________________________________________________________________________________________________
# activation_42 (Activation)      (None, 14, 14, 64)   0           batchnorm-3b-branch1a_split1[0][0
# __________________________________________________________________________________________________
# activation_44 (Activation)      (None, 14, 14, 64)   0           batchnorm-3b-branch1a_split2[0][0
# __________________________________________________________________________________________________
# activation_46 (Activation)      (None, 14, 14, 64)   0           batchnorm-3b-branch1a_split3[0][0
# __________________________________________________________________________________________________
# activation_48 (Activation)      (None, 14, 14, 64)   0           batchnorm-3b-branch1a_split4[0][0
# __________________________________________________________________________________________________
# conv2d-3b-branch1b_split1 (Conv (None, 14, 14, 64)   36928       activation_42[0][0]
# __________________________________________________________________________________________________
# conv2d-3b-branch1b_split2 (Conv (None, 14, 14, 64)   36928       activation_44[0][0]
# __________________________________________________________________________________________________
# conv2d-3b-branch1b_split3 (Conv (None, 14, 14, 64)   36928       activation_46[0][0]
# __________________________________________________________________________________________________
# conv2d-3b-branch1b_split4 (Conv (None, 14, 14, 64)   36928       activation_48[0][0]
# __________________________________________________________________________________________________
# batchnorm-3b-branch1b_split1 (B (None, 14, 14, 64)   256         conv2d-3b-branch1b_split1[0][0]
# __________________________________________________________________________________________________
# batchnorm-3b-branch1b_split2 (B (None, 14, 14, 64)   256         conv2d-3b-branch1b_split2[0][0]
# __________________________________________________________________________________________________
# batchnorm-3b-branch1b_split3 (B (None, 14, 14, 64)   256         conv2d-3b-branch1b_split3[0][0]
# __________________________________________________________________________________________________
# batchnorm-3b-branch1b_split4 (B (None, 14, 14, 64)   256         conv2d-3b-branch1b_split4[0][0]
# __________________________________________________________________________________________________
# activation_43 (Activation)      (None, 14, 14, 64)   0           batchnorm-3b-branch1b_split1[0][0
# __________________________________________________________________________________________________
# activation_45 (Activation)      (None, 14, 14, 64)   0           batchnorm-3b-branch1b_split2[0][0
# __________________________________________________________________________________________________
# activation_47 (Activation)      (None, 14, 14, 64)   0           batchnorm-3b-branch1b_split3[0][0
# __________________________________________________________________________________________________
# activation_49 (Activation)      (None, 14, 14, 64)   0           batchnorm-3b-branch1b_split4[0][0
# __________________________________________________________________________________________________
# concat3b (Concatenate)          (None, 14, 14, 256)  0           activation_43[0][0]
#                                                                  activation_45[0][0]
#                                                                  activation_47[0][0]
#                                                                  activation_49[0][0]
# __________________________________________________________________________________________________
# conv2d-trans3b (Conv2D)         (None, 14, 14, 512)  131584      concat3b[0][0]
# __________________________________________________________________________________________________
# batchnorm-trans3b (BatchNormali (None, 14, 14, 512)  2048        conv2d-trans3b[0][0]
# __________________________________________________________________________________________________
# activation_50 (Activation)      (None, 14, 14, 512)  0           batchnorm-trans3b[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 14, 14, 512)  0           activation_50[0][0]
#                                                                  activation_41[0][0]
# __________________________________________________________________________________________________
# activation_51 (Activation)      (None, 14, 14, 512)  0           add_5[0][0]
# __________________________________________________________________________________________________
# lambda_21 (Lambda)              (None, 14, 14, 64)   0           activation_51[0][0]
# __________________________________________________________________________________________________
# lambda_22 (Lambda)              (None, 14, 14, 64)   0           activation_51[0][0]
# __________________________________________________________________________________________________
# lambda_23 (Lambda)              (None, 14, 14, 64)   0           activation_51[0][0]
# __________________________________________________________________________________________________
# lambda_24 (Lambda)              (None, 14, 14, 64)   0           activation_51[0][0]
# __________________________________________________________________________________________________
# conv2d-3c-branch1a_split1 (Conv (None, 14, 14, 64)   4160        lambda_21[0][0]
# __________________________________________________________________________________________________
# conv2d-3c-branch1a_split2 (Conv (None, 14, 14, 64)   4160        lambda_22[0][0]
# __________________________________________________________________________________________________
# conv2d-3c-branch1a_split3 (Conv (None, 14, 14, 64)   4160        lambda_23[0][0]
# __________________________________________________________________________________________________
# conv2d-3c-branch1a_split4 (Conv (None, 14, 14, 64)   4160        lambda_24[0][0]
# __________________________________________________________________________________________________
# batchnorm-3c-branch1a_split1 (B (None, 14, 14, 64)   256         conv2d-3c-branch1a_split1[0][0]
# __________________________________________________________________________________________________
# batchnorm-3c-branch1a_split2 (B (None, 14, 14, 64)   256         conv2d-3c-branch1a_split2[0][0]
# __________________________________________________________________________________________________
# batchnorm-3c-branch1a_split3 (B (None, 14, 14, 64)   256         conv2d-3c-branch1a_split3[0][0]
# __________________________________________________________________________________________________
# batchnorm-3c-branch1a_split4 (B (None, 14, 14, 64)   256         conv2d-3c-branch1a_split4[0][0]
# __________________________________________________________________________________________________
# activation_52 (Activation)      (None, 14, 14, 64)   0           batchnorm-3c-branch1a_split1[0][0
# __________________________________________________________________________________________________
# activation_54 (Activation)      (None, 14, 14, 64)   0           batchnorm-3c-branch1a_split2[0][0
# __________________________________________________________________________________________________
# activation_56 (Activation)      (None, 14, 14, 64)   0           batchnorm-3c-branch1a_split3[0][0
# __________________________________________________________________________________________________
# activation_58 (Activation)      (None, 14, 14, 64)   0           batchnorm-3c-branch1a_split4[0][0
# __________________________________________________________________________________________________
# conv2d-3c-branch1b_split1 (Conv (None, 14, 14, 64)   36928       activation_52[0][0]
# __________________________________________________________________________________________________
# conv2d-3c-branch1b_split2 (Conv (None, 14, 14, 64)   36928       activation_54[0][0]
# __________________________________________________________________________________________________
# conv2d-3c-branch1b_split3 (Conv (None, 14, 14, 64)   36928       activation_56[0][0]
# __________________________________________________________________________________________________
# conv2d-3c-branch1b_split4 (Conv (None, 14, 14, 64)   36928       activation_58[0][0]
# __________________________________________________________________________________________________
# batchnorm-3c-branch1b_split1 (B (None, 14, 14, 64)   256         conv2d-3c-branch1b_split1[0][0]
# __________________________________________________________________________________________________
# batchnorm-3c-branch1b_split2 (B (None, 14, 14, 64)   256         conv2d-3c-branch1b_split2[0][0]
# __________________________________________________________________________________________________
# batchnorm-3c-branch1b_split3 (B (None, 14, 14, 64)   256         conv2d-3c-branch1b_split3[0][0]
# __________________________________________________________________________________________________
# batchnorm-3c-branch1b_split4 (B (None, 14, 14, 64)   256         conv2d-3c-branch1b_split4[0][0]
# __________________________________________________________________________________________________
# activation_53 (Activation)      (None, 14, 14, 64)   0           batchnorm-3c-branch1b_split1[0][0
# __________________________________________________________________________________________________
# activation_55 (Activation)      (None, 14, 14, 64)   0           batchnorm-3c-branch1b_split2[0][0
# __________________________________________________________________________________________________
# activation_57 (Activation)      (None, 14, 14, 64)   0           batchnorm-3c-branch1b_split3[0][0
# __________________________________________________________________________________________________
# activation_59 (Activation)      (None, 14, 14, 64)   0           batchnorm-3c-branch1b_split4[0][0
# __________________________________________________________________________________________________
# concat3c (Concatenate)          (None, 14, 14, 256)  0           activation_53[0][0]
#                                                                  activation_55[0][0]
#                                                                  activation_57[0][0]
#                                                                  activation_59[0][0]
# __________________________________________________________________________________________________
# conv2d-trans3c (Conv2D)         (None, 14, 14, 512)  131584      concat3c[0][0]
# __________________________________________________________________________________________________
# batchnorm-trans3c (BatchNormali (None, 14, 14, 512)  2048        conv2d-trans3c[0][0]
# __________________________________________________________________________________________________
# activation_60 (Activation)      (None, 14, 14, 512)  0           batchnorm-trans3c[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 14, 14, 512)  0           activation_60[0][0]
#                                                                  activation_51[0][0]
# __________________________________________________________________________________________________
# activation_61 (Activation)      (None, 14, 14, 512)  0           add_6[0][0]
# __________________________________________________________________________________________________
# lambda_25 (Lambda)              (None, 14, 14, 64)   0           activation_61[0][0]
# __________________________________________________________________________________________________
# lambda_26 (Lambda)              (None, 14, 14, 64)   0           activation_61[0][0]
# __________________________________________________________________________________________________
# lambda_27 (Lambda)              (None, 14, 14, 64)   0           activation_61[0][0]
# __________________________________________________________________________________________________
# lambda_28 (Lambda)              (None, 14, 14, 64)   0           activation_61[0][0]
# __________________________________________________________________________________________________
# conv2d-3d-branch1a_split1 (Conv (None, 14, 14, 64)   4160        lambda_25[0][0]
# __________________________________________________________________________________________________
# conv2d-3d-branch1a_split2 (Conv (None, 14, 14, 64)   4160        lambda_26[0][0]
# __________________________________________________________________________________________________
# conv2d-3d-branch1a_split3 (Conv (None, 14, 14, 64)   4160        lambda_27[0][0]
# __________________________________________________________________________________________________
# conv2d-3d-branch1a_split4 (Conv (None, 14, 14, 64)   4160        lambda_28[0][0]
# __________________________________________________________________________________________________
# batchnorm-3d-branch1a_split1 (B (None, 14, 14, 64)   256         conv2d-3d-branch1a_split1[0][0]
# __________________________________________________________________________________________________
# batchnorm-3d-branch1a_split2 (B (None, 14, 14, 64)   256         conv2d-3d-branch1a_split2[0][0]
# __________________________________________________________________________________________________
# batchnorm-3d-branch1a_split3 (B (None, 14, 14, 64)   256         conv2d-3d-branch1a_split3[0][0]
# __________________________________________________________________________________________________
# batchnorm-3d-branch1a_split4 (B (None, 14, 14, 64)   256         conv2d-3d-branch1a_split4[0][0]
# __________________________________________________________________________________________________
# activation_62 (Activation)      (None, 14, 14, 64)   0           batchnorm-3d-branch1a_split1[0][0
# __________________________________________________________________________________________________
# activation_64 (Activation)      (None, 14, 14, 64)   0           batchnorm-3d-branch1a_split2[0][0
# __________________________________________________________________________________________________
# activation_66 (Activation)      (None, 14, 14, 64)   0           batchnorm-3d-branch1a_split3[0][0
# ...
# activation_140 (Activation)     (None, 4, 4, 2048)   0           batchnorm-trans5a[0][0]
# __________________________________________________________________________________________________
# batchnorm-5a-branch2 (BatchNorm (None, 4, 4, 2048)   8192        conv2d-5a-branch2[0][0]
# __________________________________________________________________________________________________
# add_14 (Add)                    (None, 4, 4, 2048)   0           activation_140[0][0]
#                                                                  batchnorm-5a-branch2[0][0]
# __________________________________________________________________________________________________
# activation_141 (Activation)     (None, 4, 4, 2048)   0           add_14[0][0]
# __________________________________________________________________________________________________
# lambda_57 (Lambda)              (None, 4, 4, 512)    0           activation_141[0][0]
# __________________________________________________________________________________________________
# lambda_58 (Lambda)              (None, 4, 4, 512)    0           activation_141[0][0]
# __________________________________________________________________________________________________
# lambda_59 (Lambda)              (None, 4, 4, 512)    0           activation_141[0][0]
# __________________________________________________________________________________________________
# lambda_60 (Lambda)              (None, 4, 4, 512)    0           activation_141[0][0]
# __________________________________________________________________________________________________
# conv2d-5b-branch1a_split1 (Conv (None, 4, 4, 256)    131328      lambda_57[0][0]
# __________________________________________________________________________________________________
# conv2d-5b-branch1a_split2 (Conv (None, 4, 4, 256)    131328      lambda_58[0][0]
# __________________________________________________________________________________________________
# conv2d-5b-branch1a_split3 (Conv (None, 4, 4, 256)    131328      lambda_59[0][0]
# __________________________________________________________________________________________________
# conv2d-5b-branch1a_split4 (Conv (None, 4, 4, 256)    131328      lambda_60[0][0]
# __________________________________________________________________________________________________
# batchnorm-5b-branch1a_split1 (B (None, 4, 4, 256)    1024        conv2d-5b-branch1a_split1[0][0]
# __________________________________________________________________________________________________
# batchnorm-5b-branch1a_split2 (B (None, 4, 4, 256)    1024        conv2d-5b-branch1a_split2[0][0]
# __________________________________________________________________________________________________
# batchnorm-5b-branch1a_split3 (B (None, 4, 4, 256)    1024        conv2d-5b-branch1a_split3[0][0]
# __________________________________________________________________________________________________
# batchnorm-5b-branch1a_split4 (B (None, 4, 4, 256)    1024        conv2d-5b-branch1a_split4[0][0]
# __________________________________________________________________________________________________
# activation_142 (Activation)     (None, 4, 4, 256)    0           batchnorm-5b-branch1a_split1[0][0
# __________________________________________________________________________________________________
# activation_144 (Activation)     (None, 4, 4, 256)    0           batchnorm-5b-branch1a_split2[0][0
# __________________________________________________________________________________________________
# activation_146 (Activation)     (None, 4, 4, 256)    0           batchnorm-5b-branch1a_split3[0][0
# __________________________________________________________________________________________________
# activation_148 (Activation)     (None, 4, 4, 256)    0           batchnorm-5b-branch1a_split4[0][0
# __________________________________________________________________________________________________
# conv2d-5b-branch1b_split1 (Conv (None, 4, 4, 256)    590080      activation_142[0][0]
# __________________________________________________________________________________________________
# conv2d-5b-branch1b_split2 (Conv (None, 4, 4, 256)    590080      activation_144[0][0]
# __________________________________________________________________________________________________
# conv2d-5b-branch1b_split3 (Conv (None, 4, 4, 256)    590080      activation_146[0][0]
# __________________________________________________________________________________________________
# conv2d-5b-branch1b_split4 (Conv (None, 4, 4, 256)    590080      activation_148[0][0]
# __________________________________________________________________________________________________
# batchnorm-5b-branch1b_split1 (B (None, 4, 4, 256)    1024        conv2d-5b-branch1b_split1[0][0]
# __________________________________________________________________________________________________
# batchnorm-5b-branch1b_split2 (B (None, 4, 4, 256)    1024        conv2d-5b-branch1b_split2[0][0]
# __________________________________________________________________________________________________
# batchnorm-5b-branch1b_split3 (B (None, 4, 4, 256)    1024        conv2d-5b-branch1b_split3[0][0]
# __________________________________________________________________________________________________
# batchnorm-5b-branch1b_split4 (B (None, 4, 4, 256)    1024        conv2d-5b-branch1b_split4[0][0]
# __________________________________________________________________________________________________
# activation_143 (Activation)     (None, 4, 4, 256)    0           batchnorm-5b-branch1b_split1[0][0
# __________________________________________________________________________________________________
# activation_145 (Activation)     (None, 4, 4, 256)    0           batchnorm-5b-branch1b_split2[0][0
# __________________________________________________________________________________________________
# activation_147 (Activation)     (None, 4, 4, 256)    0           batchnorm-5b-branch1b_split3[0][0
# __________________________________________________________________________________________________
# activation_149 (Activation)     (None, 4, 4, 256)    0           batchnorm-5b-branch1b_split4[0][0
# __________________________________________________________________________________________________
# concat5b (Concatenate)          (None, 4, 4, 1024)   0           activation_143[0][0]
#                                                                  activation_145[0][0]
#                                                                  activation_147[0][0]
#                                                                  activation_149[0][0]
# __________________________________________________________________________________________________
# conv2d-trans5b (Conv2D)         (None, 4, 4, 2048)   2099200     concat5b[0][0]
# __________________________________________________________________________________________________
# batchnorm-trans5b (BatchNormali (None, 4, 4, 2048)   8192        conv2d-trans5b[0][0]
# __________________________________________________________________________________________________
# activation_150 (Activation)     (None, 4, 4, 2048)   0           batchnorm-trans5b[0][0]
# __________________________________________________________________________________________________
# add_15 (Add)                    (None, 4, 4, 2048)   0           activation_150[0][0]
#                                                                  activation_141[0][0]
# __________________________________________________________________________________________________
# activation_151 (Activation)     (None, 4, 4, 2048)   0           add_15[0][0]
# __________________________________________________________________________________________________
# lambda_61 (Lambda)              (None, 4, 4, 512)    0           activation_151[0][0]
# __________________________________________________________________________________________________
# lambda_62 (Lambda)              (None, 4, 4, 512)    0           activation_151[0][0]
# __________________________________________________________________________________________________
# lambda_63 (Lambda)              (None, 4, 4, 512)    0           activation_151[0][0]
# __________________________________________________________________________________________________
# lambda_64 (Lambda)              (None, 4, 4, 512)    0           activation_151[0][0]
# __________________________________________________________________________________________________
# conv2d-5c-branch1a_split1 (Conv (None, 4, 4, 256)    131328      lambda_61[0][0]
# __________________________________________________________________________________________________
# conv2d-5c-branch1a_split2 (Conv (None, 4, 4, 256)    131328      lambda_62[0][0]
# __________________________________________________________________________________________________
# conv2d-5c-branch1a_split3 (Conv (None, 4, 4, 256)    131328      lambda_63[0][0]
# __________________________________________________________________________________________________
# conv2d-5c-branch1a_split4 (Conv (None, 4, 4, 256)    131328      lambda_64[0][0]
# __________________________________________________________________________________________________
# batchnorm-5c-branch1a_split1 (B (None, 4, 4, 256)    1024        conv2d-5c-branch1a_split1[0][0]
# __________________________________________________________________________________________________
# batchnorm-5c-branch1a_split2 (B (None, 4, 4, 256)    1024        conv2d-5c-branch1a_split2[0][0]
# __________________________________________________________________________________________________
# batchnorm-5c-branch1a_split3 (B (None, 4, 4, 256)    1024        conv2d-5c-branch1a_split3[0][0]
# __________________________________________________________________________________________________
# batchnorm-5c-branch1a_split4 (B (None, 4, 4, 256)    1024        conv2d-5c-branch1a_split4[0][0]
# __________________________________________________________________________________________________
# activation_152 (Activation)     (None, 4, 4, 256)    0           batchnorm-5c-branch1a_split1[0][0
# __________________________________________________________________________________________________
# activation_154 (Activation)     (None, 4, 4, 256)    0           batchnorm-5c-branch1a_split2[0][0
# __________________________________________________________________________________________________
# activation_156 (Activation)     (None, 4, 4, 256)    0           batchnorm-5c-branch1a_split3[0][0
# __________________________________________________________________________________________________
# activation_158 (Activation)     (None, 4, 4, 256)    0           batchnorm-5c-branch1a_split4[0][0
# __________________________________________________________________________________________________
# conv2d-5c-branch1b_split1 (Conv (None, 4, 4, 256)    590080      activation_152[0][0]
# __________________________________________________________________________________________________
# conv2d-5c-branch1b_split2 (Conv (None, 4, 4, 256)    590080      activation_154[0][0]
# __________________________________________________________________________________________________
# conv2d-5c-branch1b_split3 (Conv (None, 4, 4, 256)    590080      activation_156[0][0]
# __________________________________________________________________________________________________
# conv2d-5c-branch1b_split4 (Conv (None, 4, 4, 256)    590080      activation_158[0][0]
# __________________________________________________________________________________________________
# batchnorm-5c-branch1b_split1 (B (None, 4, 4, 256)    1024        conv2d-5c-branch1b_split1[0][0]
# __________________________________________________________________________________________________
# batchnorm-5c-branch1b_split2 (B (None, 4, 4, 256)    1024        conv2d-5c-branch1b_split2[0][0]
# __________________________________________________________________________________________________
# batchnorm-5c-branch1b_split3 (B (None, 4, 4, 256)    1024        conv2d-5c-branch1b_split3[0][0]
# __________________________________________________________________________________________________
# batchnorm-5c-branch1b_split4 (B (None, 4, 4, 256)    1024        conv2d-5c-branch1b_split4[0][0]
# __________________________________________________________________________________________________
# activation_153 (Activation)     (None, 4, 4, 256)    0           batchnorm-5c-branch1b_split1[0][0
# __________________________________________________________________________________________________
# activation_155 (Activation)     (None, 4, 4, 256)    0           batchnorm-5c-branch1b_split2[0][0
# __________________________________________________________________________________________________
# activation_157 (Activation)     (None, 4, 4, 256)    0           batchnorm-5c-branch1b_split3[0][0
# __________________________________________________________________________________________________
# activation_159 (Activation)     (None, 4, 4, 256)    0           batchnorm-5c-branch1b_split4[0][0
# __________________________________________________________________________________________________
# concat5c (Concatenate)          (None, 4, 4, 1024)   0           activation_153[0][0]
#                                                                  activation_155[0][0]
#                                                                  activation_157[0][0]
#                                                                  activation_159[0][0]
# __________________________________________________________________________________________________
# conv2d-trans5c (Conv2D)         (None, 4, 4, 2048)   2099200     concat5c[0][0]
# __________________________________________________________________________________________________
# batchnorm-trans5c (BatchNormali (None, 4, 4, 2048)   8192        conv2d-trans5c[0][0]
# __________________________________________________________________________________________________
# activation_160 (Activation)     (None, 4, 4, 2048)   0           batchnorm-trans5c[0][0]
# __________________________________________________________________________________________________
# add_16 (Add)                    (None, 4, 4, 2048)   0           activation_160[0][0]
#                                                                  activation_151[0][0]
# __________________________________________________________________________________________________
# activation_161 (Activation)     (None, 4, 4, 2048)   0           add_16[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_1 (AveragePoo (None, 2, 2, 2048)   0           activation_161[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 8192)         0           average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# fc2 (Dense)                     (None, 2)            16386       flatten_1[0][0]
# ==================================================================================================
# Total params: 26,121,986
# Trainable params: 26,053,762
# Non-trainable params: 68,224
# __________________________________________________________________________________________________

# %% [markdown]
# # References
#
# <ol>
#     <li> <i>Xie et al. (2017)</i> <a href="https://arxiv.org/pdf/1611.05431.pdf">Aggregated Residual Transformations for Deep Neural Networks</a> </li>
#     <li> <i>He et al. (2015)</i> <a href="https://www.cv-foundation.org/openaccess/content_cvpr_2016/papers/He_Deep_Residual_Learning_CVPR_2016_paper.pdf">Deep Residual Learning for Image Recognition</a> </li>
#     <li> <i> Marco Peixeiro </i> GitHub repository : <a href="https://github.com/marcopeix/Deep_Learning_AI/blob/master/4.Convolutional%20Neural%20Networks/2.Deep%20Convolutional%20Models/Residual%20Networks.ipynb">Residual Networks</a></li>
#     <li> GitHub Repository: <a href="https://github.com/taki0112/ResNeXt-Tensorflow#what-is-the-transition-">ResNeXt-Tensorflow</a></li>
# </ol>
